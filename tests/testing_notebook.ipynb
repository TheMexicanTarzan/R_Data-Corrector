# %%
import sys
import os

# Get the current working directory and go up one level to the parent
# This assumes your notebook is inside a folder (e.g., 'notebooks/')
# and 'src/' is a sibling to that folder.
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the project root to the system path if it's not there already
if project_root not in sys.path:
    sys.path.append(project_root)

# Now you can import using standard 'src' syntax (no dots at the start)
from src.input_handlers.csv_reader import read_csv_files_to_polars

# %%
data = read_csv_files_to_polars()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data = read_csv_files_to_polars()
#
# File ~\Desktop\KaxaNuk\R_Data-Corrector\src\input_handlers\csv_reader.py:58, in read_csv_files_to_polars(directory_path, lazy, max_files, file_pattern, include_files, exclude_files)
#      56 # Validate directory
#      57 if not directory.exists():
# ---> 58     raise ValueError(f"Directory does not exist: {directory_path}")
#      60 if not directory.is_dir():
#      61     raise ValueError(f"Path is not a directory: {directory_path}")
#
# ValueError: Directory does not exist: ../../Input/Data
